# %% [markdown]
# <a href="https://colab.research.google.com/github/parth025sharma/ML/blob/master/opencvvvv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
#image reading
img=cv2.imread('ch.jpeg',0)
img1=cv2.imread('ch.jpeg',1)
img2=cv2.imread('ch.jpeg',-1)
#1 means image is same color cahannel --GRB OR RGB
#0 means no color cahannel 
#-1 maintains the image transperancy ----
img
# Out:
# array([[11, 18, 28, ..., 77, 87, 95],
#        [10, 17, 26, ..., 77, 87, 95],
#        [ 9, 15, 24, ..., 77, 87, 94],
#        ...,
#        [15, 15, 15, ..., 12, 11, 11],
#        [15, 15, 15, ..., 12, 11, 11],
#        [15, 15, 15, ..., 12, 11, 11]], dtype=uint8)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (172, 293)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=293x172 at 0x7FB18168B080>

# %%
cv2_imshow(img1[0:130,0:150])
# Out:
# <PIL.Image.Image image mode=RGB size=150x130 at 0x7FB17EE02208>

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=293x172 at 0x7FB17EE020B8>

# %%
c
